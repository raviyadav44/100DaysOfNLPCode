# %% [markdown]
# ## Categorizing and Tagging Words

# %% [markdown]
# The process of classifying words into their parts-of-speech and labeling them accord- ingly is known as part-of-speech tagging, POS tagging, or simply tagging. Parts- of-speech are also known as word classes or lexical categories. The collection of tags used for a particular task is known as a tagset. Our emphasis in this chapter is on exploiting tags, and tagging text automatically.

# %%
import nltk
# %matplotlib inline

# %%
text = nltk.word_tokenize("And now for something completely different")

# %%
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %% [markdown]
# and is CC, a coordinating conjunction; now and completely are RB, or adverbs; for is IN, a preposition; something is NN, a noun; and different is JJ, an adjective.

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")

# %%
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %% [markdown]
# ### Representing Tagged Tokens

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')

# %%
tagged_token
# Out:
# ('fly', 'NN')

# %%
tagged_token[0]
# Out:
# 'fly'

# %%
sent = '''
The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
Fulton/NP-tl County/NN-tl purchasing/VBG departments/NNS which/WDT it/PPS
said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
interest/NN of/IN both/ABX governments/NNS ''/'' ./.
'''

# %%
[nltk.tag.str2tuple(t) for t in sent.split()]
# Out:
# [('The', 'AT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'AT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'AP'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('AMONG', 'IN'),
#  ('them', 'PPO'),
#  ('the', 'AT'),
#  ('Atlanta', 'NP'),
#  ('and', 'CC'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('purchasing', 'VBG'),
#  ('departments', 'NNS'),
#  ('which', 'WDT'),
#  ('it', 'PPS'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('ARE', 'BER'),
#  ('well', 'QL'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VB'),
#  ('to', 'IN'),
#  ('the', 'AT'),
#  ('best', 'JJT'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'ABX'),
#  ('governments', 'NNS'),
#  ("''", "''"),
#  ('.', '.')]

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
from nltk.corpus import brown

# %%
brown_news_tagged = brown.tagged_words(categories='news')

# %%
brown_news_tagged
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)

# %%
tag_fd.keys()
# Out:
# dict_keys(['AT', 'NP-TL', 'NN-TL', 'JJ-TL', 'VBD', 'NR', 'NN', 'IN', 'NP$', 'JJ', '``', "''", 'CS', 'DTI', 'NNS', '.', 'RBR', ',', 'WDT', 'HVD', 'VBZ', 'CC', 'IN-TL', 'BEDZ', 'VBN', 'NP', 'BEN', 'TO', 'VB', 'RB', 'DT', 'PPS', 'DOD', 'AP', 'BER', 'HV', 'DTS', 'VBG', 'PPO', 'QL', 'JJT', 'ABX', 'NN-HL', 'VBN-HL', 'WRB', 'CD', 'MD', 'BE', 'JJR', 'VBG-TL', 'BEZ', 'NN$-TL', 'HVZ', 'ABN', 'PN', 'PPSS', 'PP$', 'DO', 'NN$', 'NNS-HL', 'WPS', '*', 'EX', 'VB-HL', ':', '(', ')', 'NNS-TL', 'NPS', 'JJS', 'RP', '--', 'BED', 'OD', 'BEG', 'AT-HL', 'VBG-HL', 'AT-TL', 'PPL', 'DOZ', 'NP-HL', 'NR$', 'DOD*', 'BEDZ*', ',-HL', 'CC-TL', 'MD*', 'NNS$', 'PPSS+BER', "'", 'PPSS+BEM', 'CD-TL', 'RBT', '(-HL', ')-HL', 'MD-HL', 'VBZ-HL', 'IN-HL', 'JJ-HL', 'PPLS', 'CD-HL', 'WPO', 'JJS-TL', 'ABL', 'BER-HL', 'PPS+HVZ', 'VBD-HL', 'RP-HL', 'MD*-HL', 'AP-HL', 'CS-HL', 'DT$', 'HVN', 'FW-IN', 'FW-DT', 'VBN-TL', 'NR-TL', 'NNS$-TL', 'FW-NN', 'HVG', 'DTX', 'OD-TL', 'BEM', 'RB-HL', 'PPSS+MD', 'NPS-HL', 'NPS$', 'WP$', 'NN-TL-HL', 'CC-HL', 'PPS+BEZ', 'AP-TL', 'UH-TL', 'BEZ-HL', 'TO-HL', 'DO*', 'VBN-TL-HL', 'NNS-TL-HL', 'DT-HL', 'BE-HL', 'DOZ*', 'QLP', 'JJR-HL', 'PPSS+HVD', 'FW-IN+NN', 'PP$$', 'JJT-HL', 'NP-TL-HL', 'NPS-TL', 'MD+HV', 'NP$-TL', 'OD-HL', 'JJR-TL', 'VBD-TL', 'DT+BEZ', 'EX+BEZ', 'PPSS+HV', ':-HL', 'PPS+MD', 'UH', 'FW-CC', 'FW-NNS', 'BEDZ-HL', 'NN$-HL', '.-HL', 'HVD*', 'BEZ*', 'AP$', 'NP+BEZ', 'FW-AT-TL', 'VB-TL', 'RB-TL', 'MD-TL', 'PN+HVZ', 'FW-JJ-TL', 'FW-NN-TL', 'ABN-HL', 'PPS+BEZ-HL', 'NR-HL', 'HVD-HL', 'RB$', 'FW-AT-HL', 'DO-HL', 'PP$-TL', 'FW-IN-TL', 'WPS+BEZ', '*-HL', 'DTI-HL', 'PN-HL', 'CD$', 'BER*', 'NNS$-HL', 'PN$', 'BER-TL', 'TO-TL', 'FW-JJ', 'BED*', 'RB+BEZ', 'VB+PPO', 'PPSS-HL', 'HVZ*', 'FW-IN+NN-TL', 'FW-IN+AT-TL', 'NN-NC', 'JJ-NC', 'NR$-TL', 'FW-PP$-NC', 'FW-VB', 'FW-VB-NC', 'JJR-NC', 'NPS$-TL', 'QL-TL', 'FW-AT', 'FW-*', 'FW-CD', 'WQL', 'FW-WDT', 'WDT+BEZ'])

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)

# %%
list(nltk.FreqDist(a[1] for (a, b) in word_tag_pairs if b[1] == 'N'))
# Out:
# []

# %%
wsj = nltk.corpus.treebank.tagged_words()

# %%
word_tag_fd = nltk.FreqDist(wsj)

# %%
[word + "/" + tag for (word, tag) in word_tag_fd if tag.startswith('V')]
# Out:
# ['join/VB',
#  'is/VBZ',
#  'publishing/VBG',
#  'was/VBD',
#  'named/VBN',
#  'used/VBN',
#  'make/VB',
#  'has/VBZ',
#  'caused/VBN',
#  'exposed/VBN',
#  'reported/VBD',
#  'enters/VBZ',
#  'causing/VBG',
#  'show/VBP',
#  'said/VBD',
#  'makes/VBZ',
#  'stopped/VBD',
#  'using/VBG',
#  'were/VBD',
#  'reported/VBN',
#  'appear/VBP',
#  'bring/VB',
#  "'re/VBP",
#  'talking/VBG',
#  'heard/VBD',
#  'having/VBG',
#  'studied/VBD',
#  'have/VBP',
#  'are/VBP',
#  'led/VBD',
#  'making/VBG',
#  'replaced/VBN',
#  'sold/VBN',
#  'worked/VBD',
#  'died/VBN',
#  'expected/VBN',
#  'surviving/VBG',
#  'including/VBG',
#  'diagnosed/VBN',
#  'study/VBP',
#  'appears/VBZ',
#  'be/VB',
#  'studied/VBN',
#  'industrialized/VBN',
#  'owned/VBN',
#  'support/VB',
#  'argue/VBP',
#  'regulate/VB',
#  'found/VBN',
#  'does/VBZ',
#  'have/VB',
#  'classified/VBN',
#  'according/VBG',
#  'rejected/VBN',
#  'explained/VBD',
#  'imposed/VBD',
#  'remaining/VBG',
#  'outlawed/VBN',
#  'made/VBD',
#  'dumped/VBD',
#  'imported/VBN',
#  'poured/VBD',
#  'mixed/VBD',
#  'described/VBD',
#  'hung/VBD',
#  'ventilated/VBD',
#  "'s/VBZ",
#  'contracted/VBD',
#  'recognize/VB',
#  'took/VBD',
#  'continued/VBD',
#  'slide/VB',
#  'expect/VBP',
#  'tracked/VBN',
#  'eased/VBD',
#  'ended/VBD',
#  'assume/VBP',
#  'continues/VBZ',
#  'lengthened/VBD',
#  'thought/VBN',
#  'indicate/VB',
#  'declining/VBG',
#  'permit/VBP',
#  'retain/VB',
#  'considered/VBN',
#  'rising/VBG',
#  'capture/VB',
#  'watch/VBP',
#  'reached/VBD',
#  'blip/VB',
#  'blip/VBP',
#  'rose/VBD',
#  'continue/VBP',
#  'pour/VB',
#  'grew/VBD',
#  'beat/VBP',
#  'vary/VB',
#  'go/VB',
#  'yielding/VBG',
#  'had/VBD',
#  'invests/VBZ',
#  'waiving/VBG',
#  'boosts/VBZ',
#  'fell/VBD',
#  'slid/VBD',
#  'holds/VBZ',
#  'elected/VBN',
#  'succeeds/VBZ',
#  'resigned/VBD',
#  'approved/VBD',
#  'holding/VBG',
#  'expects/VBZ',
#  'obtain/VB',
#  'complete/VB',
#  'completed/VBD',
#  'based/VBN',
#  'employs/VBZ',
#  'suspended/VBD',
#  'lifted/VBN',
#  'acts/VBZ',
#  'issue/VB',
#  'dropped/VBD',
#  'lift/VB',
#  'ensnarled/VBN',
#  'cutting/VBG',
#  'voted/VBN',
#  'raise/VB',
#  'act/VB',
#  'default/VB',
#  'oversee/VB',
#  'been/VBN',
#  'manufacturing/VBG',
#  'jet/VBP',
#  'settled/VBD',
#  'decided/VBD',
#  'treat/VB',
#  'prove/VB',
#  'expand/VB',
#  'receiving/VBG',
#  'joined/VBD',
#  'followed/VBD',
#  'raced/VBD',
#  'welcomed/VBD',
#  'held/VBN',
#  'banned/VBN',
#  'hauled/VBD',
#  'drooled/VBD',
#  'pointed/VBD',
#  'squeezed/VBD',
#  'boarding/VBG',
#  'renovated/VBN',
#  'fed/VBD',
#  'Knowing/VBG',
#  'eat/VBP',
#  'gave/VBD',
#  'say/VBP',
#  'tempts/VBZ',
#  'return/VB',
#  'looking/VBG',
#  'registered/VBD',
#  'reflecting/VBG',
#  'released/VBD',
#  'showed/VBD',
#  'casting/VBG',
#  'stood/VBD',
#  'increased/VBD',
#  'began/VBD',
#  'prolonged/VBN',
#  'remain/VB',
#  'recorded/VBN',
#  'accumulated/VBN',
#  'trying/VBG',
#  'keep/VB',
#  'announced/VBD',
#  'introduce/VB',
#  'offered/VBN',
#  'give/VBP',
#  'maintaining/VBG',
#  'increasing/VBG',
#  'become/VBN',
#  'underscore/VBP',
#  'increase/VB',
#  'cost/VB',
#  'lowered/VBD',
#  'guaranteed/VBN',
#  'costs/VBZ',
#  'announce/VB',
#  'awards/VBZ',
#  'reward/VB',
#  'meet/VBP',
#  'exceed/VBP',
#  'spent/VBD',
#  'shore/VB',
#  'totaled/VBD',
#  'matters/VBZ',
#  'paying/VBG',
#  'doing/VBG',
#  'gaining/VBG',
#  'recorded/VBD',
#  'According/VBG',
#  'bowed/VBD',
#  'saying/VBG',
#  'justify/VB',
#  'leaves/VBZ',
#  'proposed/VBN',
#  'acquire/VB',
#  'says/VBZ',
#  'values/VBZ',
#  'suffer/VB',
#  'related/VBN',
#  'improved/VBN',
#  'did/VBD',
#  'come/VB',
#  'evaluated/VBD',
#  'raising/VBG',
#  'seemed/VBD',
#  'got/VBD',
#  'take/VB',
#  'added/VBD',
#  'noted/VBD',
#  'worried/VBN',
#  'owns/VBZ',
#  'emerges/VBZ',
#  'attracts/VBZ',
#  'withdraw/VB',
#  'speed/VB',
#  'proposed/VBD',
#  'asserted/VBD',
#  'cluttered/VBN',
#  'turned/VBD',
#  'seeking/VBG',
#  'refile/VB',
#  'hopes/VBZ',
#  'expedited/VBN',
#  'closed/VBD',
#  'operating/VBG',
#  'succeed/VBP',
#  'retired/VBN',
#  'ordered/VBN',
#  'refund/VB',
#  'collected/VBN',
#  'required/VBN',
#  'ordered/VBD',
#  'received/VBN',
#  'moved/VBN',
#  'begin/VB',
#  'entertain/VB',
#  'block/VB',
#  'appealing/VBG',
#  'underlying/VBG',
#  'considering/VBG',
#  'determined/VBN',
#  'made/VBN',
#  'force/VB',
#  'slash/VB',
#  'tracking/VBG',
#  'changed/VBN',
#  'completed/VBN',
#  'disputed/VBN',
#  'pay/VB',
#  'upheld/VBD',
#  'found/VBD',
#  'audit/VB',
#  'collecting/VBG',
#  'ruled/VBD',
#  'refunded/VBN',
#  'set/VBD',
#  'faces/VBZ',
#  'estimated/VBN',
#  'hope/VBP',
#  'set/VB',
#  'involving/VBG',
#  'rule/VB',
#  'setting/VBG',
#  'compared/VBN',
#  'inched/VBD',
#  'benefited/VBD',
#  'arising/VBG',
#  'doubled/VBD',
#  'opened/VBD',
#  'manufacture/VB',
#  'located/VBN',
#  'help/VB',
#  'meet/VB',
#  'diversifying/VBG',
#  'produce/VB',
#  'depend/VB',
#  'tied/VBD',
#  'filed/VBN',
#  'pending/VBG',
#  'disclosed/VBD',
#  'providing/VBG',
#  'heads/VBZ',
#  'scrapped/VBN',
#  'working/VBG',
#  'anticipated/VBN',
#  'attached/VBD',
#  'want/VB',
#  'fund/VB',
#  'include/VB',
#  'anticipates/VBZ',
#  'needing/VBG',
#  'beginning/VBG',
#  'called/VBD',
#  'caused/VBD',
#  'jump/VB',
#  'close/VB',
#  'link/VB',
#  'complicate/VB',
#  'believe/VBP',
#  'do/VB',
#  'do/VBP',
#  'include/VBP',
#  'describe/VBP',
#  'being/VBG',
#  'require/VB',
#  'contain/VB',
#  'face/VB',
#  'roll/VB',
#  'compete/VB',
#  'believes/VBZ',
#  'priced/VBN',
#  'receive/VB',
#  'own/VBP',
#  'occur/VB',
#  'set/VBN',
#  'leave/VB',
#  'decide/VB',
#  'applied/VBN',
#  'trade/VB',
#  'calculate/VBP',
#  'transferring/VBG',
#  'favored/VBD',
#  'report/VB',
#  'posted/VBD',
#  'existed/VBN',
#  'incurred/VBN',
#  'reached/VBN',
#  'work/VB',
#  'Regarded/VBN',
#  'paid/VBN',
#  'includes/VBZ',
#  'came/VBD',
#  'continue/VB',
#  'succeed/VB',
#  'claiming/VBG',
#  'removed/VBD',
#  'watching/VBG',
#  'failing/VBG',
#  'honor/VB',
#  'improve/VB',
#  'placed/VBD',
#  'varying/VBG',
#  'growing/VBG',
#  'harms/VBZ',
#  'trading/VBG',
#  'offending/VBG',
#  'hurting/VBG',
#  'discouraging/VBG',
#  'deterring/VBG',
#  'investing/VBG',
#  'marketing/VBG',
#  'lauded/VBD',
#  'creating/VBG',
#  'trained/VBN',
#  'pursue/VB',
#  'instituted/VBN',
#  'aid/VB',
#  'initialing/VBG',
#  'amending/VBG',
#  'introducing/VBG',
#  'protect/VB',
#  'compel/VB',
#  'showing/VBG',
#  'vowed/VBN',
#  'enact/VB',
#  'apply/VB',
#  'deemed/VBN',
#  'pose/VB',
#  'specializing/VBG',
#  'combined/VBN',
#  'protecting/VBG',
#  'prompted/VBD',
#  'tells/VBZ',
#  'removed/VBN',
#  'craft/VB',
#  'concerned/VBN',
#  'continuing/VBG',
#  'complained/VBN',
#  'requires/VBZ',
#  'deemed/VBD',
#  'merit/VB',
#  'accelerated/VBN',
#  'ask/VB',
#  'halve/VB',
#  'developing/VBG',
#  'believed/VBN',
#  'called/VBN',
#  'aspires/VBZ',
#  'reach/VB',
#  'met/VBD',
#  'feels/VBZ',
#  'solved/VBN',
#  'wants/VBZ',
#  'forgiven/VBN',
#  'stand/VBP',
#  'CHANGED/VBD',
#  'launched/VBN',
#  'use/VB',
#  'stored/VBD',
#  'built/VBN',
#  'triggered/VBD',
#  'store/VB',
#  'developed/VBD',
#  'became/VBD',
#  'adapted/VBD',
#  'allow/VBP',
#  'share/VB',
#  'offer/VB',
#  'entered/VBD',
#  'total/VBP',
#  'acquired/VBD',
#  'sells/VBZ',
#  'preferred/VBN',
#  'gives/VBZ',
#  'raised/VBN',
#  'scheduled/VBN',
#  'brought/VBN',
#  'operate/VBP',
#  'started/VBD',
#  'increased/VBN',
#  'reaches/VBZ',
#  'start/VB',
#  'producing/VBG',
#  'developed/VBN',
#  'Following/VBG',
#  'led/VBN',
#  'divest/VB',
#  'approved/VBN',
#  'produced/VBN',
#  'denied/VBN',
#  'requested/VBN',
#  'covered/VBN',
#  'grant/VB',
#  'watch/VB',
#  'assembled/VBN',
#  'stepping/VBG',
#  'turn/VB',
#  'direct/VB',
#  'reduce/VB',
#  'curb/VB',
#  'achieved/VBN',
#  'maintained/VBN',
#  'left/VBN',
#  'cut/VBD',
#  'wallowing/VBG',
#  'controlling/VBG',
#  'seek/VB',
#  'resume/VB',
#  'running/VBG',
#  'cut/VB',
#  'assisted/VBN',
#  'bought/VBD',
#  'totaling/VBG',
#  'placed/VBN',
#  'went/VBD',
#  'snapped/VBD',
#  'put/VBN',
#  'offering/VBG',
#  'linked/VBN',
#  'offered/VBD',
#  'offer/VBP',
#  'designed/VBN',
#  'eliminate/VB',
#  'decline/VBP',
#  'forces/VBZ',
#  'redeploy/VB',
#  'channel/VBP',
#  'reducing/VBG',
#  'addressing/VBG',
#  'boosted/VBN',
#  'buying/VBG',
#  'issued/VBN',
#  'expanding/VBG',
#  'agreed/VBD',
#  'extend/VB',
#  'file/VB',
#  'giving/VBG',
#  'attempts/VBZ',
#  'incorporated/VBN',
#  'advertised/VBN',
#  'expire/VB',
#  'announced/VBN',
#  'marks/VBZ',
#  'reflects/VBZ',
#  'surged/VBD',
#  'follows/VBZ',
#  'Pick/VB',
#  'sweeping/VBG',
#  'traded/VBN',
#  'invest/VBP',
#  'registered/VBN',
#  'ranged/VBN',
#  'capped/VBN',
#  'kicked/VBN',
#  'quips/VBZ',
#  'managing/VBG',
#  'mirrors/VBZ',
#  'focused/VBN',
#  'issuing/VBG',
#  'fixed/VBN',
#  'trade/VBP',
#  'brings/VBZ',
#  'listed/VBN',
#  'account/VBP',
#  'stake/VB',
#  'runs/VBZ',
#  'turned/VBN',
#  'scrambled/VBN',
#  'find/VB',
#  'find/VBP',
#  'sell/VB',
#  'stretching/VBG',
#  'urge/VBP',
#  'diversify/VB',
#  'hold/VB',
#  'emerging/VBG',
#  'outpaced/VBN',
#  'get/VB',
#  'burned/VBN',
#  'whipsaw/VB',
#  'tend/VBP',
#  'swing/VB',
#  'plunged/VBD',
#  'clobbered/VBN',
#  'climbed/VBN',
#  'hold/VBP',
#  'closed/VBN',
#  'skyrocketed/VBN',
#  'surged/VBN',
#  'targeted/VBN',
#  'tied/VBN',
#  'invested/VBN',
#  'jumped/VBN',
#  "'m/VBP",
#  'alarmed/VBN',
#  'see/VB',
#  'fattened/VBN',
#  'reflect/VBP',
#  'suggests/VBZ',
#  'cast/VBN',
#  'buy/VB',
#  'represent/VBP',
#  'insist/VBP',
#  'jumping/VBG',
#  'come/VBP',
#  'owed/VBD',
#  'repaid/VBN',
#  'clear/VB',
#  'say/VB',
#  'happen/VB',
#  'permitted/VBN',
#  'open/VB',
#  'crippled/VBN',
#  'settle/VB',
#  'lent/VBN',
#  'seized/VBD',
#  'amended/VBN',
#  'belongs/VBZ',
#  'settled/VBN',
#  'stressed/VBD',
#  'satisfying/VBG',
#  'settle/VBP',
#  'leveling/VBG',
#  'manufactured/VBN',
#  'failed/VBD',
#  'rise/VB',
#  'indicated/VBD',
#  'purchasing/VBG',
#  'booked/VBD',
#  'fallen/VBN',
#  'ran/VBD',
#  'adjusted/VBN',
#  'remove/VB',
#  'taper/VB',
#  'failed/VBN',
#  'revive/VB',
#  'pick/VB',
#  'asked/VBD',
#  'draw/VBP',
#  'predicting/VBG',
#  'slip/VB',
#  'cite/VBP',
#  'provide/VBP',
#  'watched/VBN',
#  'provoke/VB',
#  'lead/VB',
#  'conforms/VBZ',
#  'eases/VBZ',
#  'leading/VBG',
#  'intended/VBN',
#  'last/VB',
#  'climbing/VBG',
#  'estimated/VBD',
#  'helped/VBN',
#  'Excluding/VBG',
#  'declined/VBD',
#  'accounts/VBZ',
#  'predicted/VBD',
#  'boost/VB',
#  'adjusting/VBG',
#  'change/VB',
#  'contrast/VBP',
#  'issued/VBD',
#  'awarded/VBN',
#  'counts/VBZ',
#  'spent/VBN',
#  'slowing/VBG',
#  'signaling/VBG',
#  'purchased/VBD',
#  'delivering/VBG',
#  'consider/VBP',
#  'abating/VBG',
#  'handle/VB',
#  'lengthen/VBP',
#  'provided/VBN',
#  'gauges/VBZ',
#  'reporting/VBG',
#  'polled/VBD',
#  'import/VBP',
#  'imported/VBD',
#  'acknowledging/VBG',
#  'suspect/VB',
#  'going/VBG',
#  'numbered/VBD',
#  'included/VBD',
#  'put/VB',
#  'blamed/VBD',
#  'coupled/VBN',
#  'contributed/VBD',
#  'Judging/VBG',
#  'drink/VBP',
#  'whistle/VBP',
#  'read/VBP',
#  'talk/VBP',
#  'worry/VBP',
#  'suffer/VBP',
#  'broken/VBN',
#  'recognizing/VBG',
#  'refreshing/VBG',
#  'read/VB',
#  'belong/VB',
#  'perpetuate/VBP',
#  'carries/VBZ',
#  'think/VBP',
#  'rooted/VBN',
#  'sets/VBZ',
#  'mark/VBP',
#  'meets/VBZ',
#  'offers/VBZ',
#  'wears/VBZ',
#  'seems/VBZ',
#  'published/VBD',
#  'dominating/VBG',
#  'written/VBN',
#  'carry/VBP',
#  'call/VB',
#  'describes/VBZ',
#  'named/VBD',
#  'played/VBN',
#  'return/VBP',
#  'expands/VBZ',
#  'depending/VBG',
#  'welcomed/VBN',
#  'sidestep/VBP',
#  'abide/VB',
#  'wear/VB',
#  'rationed/VBN',
#  'fare/VBP',
#  'stand/VB',
#  'decide/VBP',
#  'run/VBP',
#  'hosted/VBD',
#  'invades/VBZ',
#  'assigned/VBN',
#  'run/VBN',
#  'talk/VB',
#  'letting/VBG',
#  'frustrating/VBG',
#  'invent/VB',
#  'fired/VBD',
#  'committed/VBD',
#  'learned/VBD',
#  'becoming/VBG',
#  'entering/VBG',
#  'bans/VBZ',
#  'launched/VBD',
#  'urged/VBD',
#  'ban/VB',
#  'visiting/VBG',
#  'advertising/VBG',
#  'opened/VBN',
#  'restricts/VBZ',
#  'designated/VBN',
#  'indicates/VBZ',
#  'carried/VBN',
#  'feel/VBP',
#  'surveyed/VBN',
#  'espouse/VBP',
#  'identified/VBD',
#  'endorsed/VBD',
#  'build/VB',
#  'draw/VB',
#  'balked/VBD',
#  'undertaking/VBG',
#  'asking/VBG',
#  'back/VB',
#  'applied/VBD',
#  'renewed/VBD',
#  'win/VB',
#  'name/VB',
#  'confirmed/VBN',
#  'tested/VBN',
#  'had/VBN',
#  'compensate/VB',
#  'establishing/VBG',
#  'strapped/VBN',
#  'terminated/VBD',
#  'twinned/VBN',
#  'ending/VBG',
#  'authorized/VBD',
#  'modify/VB',
#  'planned/VBN',
#  'operated/VBN',
#  'sold/VBD',
#  'painted/VBN',
#  'exchanging/VBG',
#  'entitles/VBZ',
#  'accrued/VBN',
#  'expire/VBP',
#  'swapped/VBN',
#  'elaborate/VB',
#  'laid/VBN',
#  'obsessed/VBN',
#  'refitting/VBG',
#  'shot/VBD',
#  'revived/VBN',
#  'contained/VBD',
#  'earns/VBZ',
#  'playing/VBG',
#  'prepared/VBN',
#  'thinking/VBG',
#  'feeling/VBG',
#  'takes/VBZ',
#  'romanticized/VBN',
#  'Filmed/VBN',
#  'seem/VBP',
#  'walk/VBP',
#  'noticing/VBG',
#  'jostle/VBP',
#  'hangs/VBZ',
#  'populated/VBN',
#  'selling/VBG',
#  'curled/VBD',
#  'spends/VBZ',
#  'sketching/VBG',
#  'returns/VBZ',
#  'condemned/VBN',
#  'calls/VBZ',
#  'competing/VBG',
#  'given/VBN',
#  'cure/VB',
#  'returning/VBG',
#  'murdered/VBN',
#  'turns/VBZ',
#  'alerts/VBZ',
#  'tuck/VB',
#  'load/VB',
#  'dreamed/VBD',
#  'lives/VBZ',
#  'resonate/VB',
#  'glamorize/VB',
#  'ends/VBZ',
#  'managed/VBN',
#  'viewed/VBN',
#  'seem/VB',
#  'executed/VBN',
#  'collaborated/VBD',
#  'needed/VBD',
#  'enabled/VBD',
#  'killed/VBD',
#  'brought/VBD',
#  'presented/VBN',
#  'deserve/VB',
#  'chopped/VBN',
#  'recommend/VB',
#  'taken/VBN',
#  'fighting/VBG',
#  'eating/VBG',
#  'drinking/VBG',
#  'celebrate/VB',
#  'mention/VBP',
#  'die/VB',
#  'seeing/VBG',
#  'discussing/VBG',
#  'worked/VBN',
#  'build/VBP',
#  'accounting/VBG',
#  'speculated/VBN',
#  'goes/VBZ',
#  'hit/VB',
#  'getting/VBG',
#  'come/VBN',
#  'scattered/VBN',
#  'ushering/VBG',
#  'attack/VB',
#  'accelerated/VBD',
#  'needs/VBZ',
#  'means/VBZ',
#  'worry/VB',
#  'prompted/VBN',
#  'Take/VB',
#  'fills/VBZ',
#  'gets/VBZ',
#  'charges/VBZ',
#  'hid/VBD',
#  'paid/VBD',
#  'convicted/VBN',
#  'wait/VB',
#  'caught/VBN',
#  'prosecute/VB',
#  'exist/VB',
#  'Stung/VBN',
#  'unleashed/VBD',
#  'shows/VBZ',
#  'Compare/VB',
#  'banning/VBG',
#  'opposed/VBN',
#  'claims/VBZ',
#  'choose/VB',
#  'telling/VBG',
#  'fail/VB',
#  'insists/VBZ',
#  'admitted/VBD',
#  'refused/VBN',
#  'blamed/VBN',
#  'know/VB',
#  'argues/VBZ',
#  'knows/VBZ',
#  'know/VBP',
#  'agree/VBP',
#  'superimposed/VBN',
#  'talks/VBZ',
#  'nurtured/VBN',
#  'dissolves/VBZ',
#  'give/VB',
#  'wanted/VBD',
#  'denies/VBZ',
#  'changed/VBD',
#  'transforming/VBG',
#  'launch/VB',
#  'created/VBN',
#  'shake/VB',
#  'attracted/VBN',
#  'featured/VBD',
#  'suggested/VBD',
#  'recalling/VBG',
#  "C'mon/VB",
#  'interjects/VBZ',
#  'introduced/VBD',
#  'interrogated/VBN',
#  'accused/VBN',
#  'tried/VBD',
#  'pass/VB',
#  'introduced/VBN',
#  'grown/VBN',
#  'gotten/VBN',
#  'devote/VB',
#  'lasted/VBD',
#  'carrying/VBG',
#  'featuring/VBG',
#  'aired/VBD',
#  'Remember/VB',
#  'Consider/VB',
#  'rusted/VBN',
#  'swim/VBP',
#  'purrs/VBZ',
#  'suing/VBG',
#  'grows/VBZ',
#  'involved/VBN',
#  'cry/VBP',
#  'responded/VBN',
#  'lying/VBG',
#  'asks/VBZ',
#  'cleaned/VBN',
#  'shrinks/VBZ',
#  'dumped/VBN',
#  'devastating/VBG',
#  'raised/VBD',
#  'building/VBG',
#  'appeared/VBD',
#  'want/VBP',
#  'quoted/VBN',
#  'asked/VBN',
#  'propelling/VBG',
#  'suggest/VBP',
#  'pursued/VBN',
#  'sparking/VBG',
#  'posing/VBG',
#  'knitted/VBN',
#  'tripled/VBN',
#  'following/VBG',
#  'pumping/VBG',
#  'forcing/VBG',
#  'known/VBN',
#  'contributing/VBG',
#  'provide/VB',
#  'spur/VB',
#  'make/VBP',
#  'falling/VBG',
#  'encourages/VBZ',
#  'resists/VBZ',
#  'coming/VBG',
#  'comes/VBZ',
#  'swelling/VBG',
#  'concentrated/VBD',
#  'spurred/VBN',
#  'move/VB',
#  'accommodate/VB',
#  'offend/VB',
#  'parallel/VB',
#  'assemble/VB',
#  'export/VB',
#  'pull/VB',
#  'consider/VB',
#  'discuss/VB',
#  'reasserts/VBZ',
#  'taking/VBG',
#  'play/VB',
#  'designing/VBG',
#  'outstrips/VBZ',
#  'outranks/VBZ',
#  'remains/VBZ',
#  'voice/VBP',
#  'convey/VBP',
#  'approach/VBP',
#  'step/VB',
#  'ease/VB',
#  'regard/VBP',
#  'try/VB',
#  'slow/VB',
#  'monopolize/VB',
#  'sew/VB',
#  'believe/VB',
#  'spotted/VBD',
#  'seen/VBN',
#  'surrendered/VBD',
#  'passed/VBN',
#  'matched/VBD',
#  'Confronted/VBN',
#  'answers/VBZ',
#  'gone/VBN',
#  'display/VB',
#  'underline/VB',
#  'fired/VBN',
#  'prosecuted/VBN',
#  'breach/VB',
#  'pleaded/VBD',
#  'won/VBD',
#  'inspired/VBD',
#  'teach/VB',
#  'left/VBD',
#  'defended/VBD',
#  'treated/VBN',
#  'casts/VBZ',
#  'enhanced/VBN',
#  'cheat/VB',
#  'violated/VBD',
#  'enforce/VB',
#  'alleged/VBD',
#  'bolster/VB',
#  'depended/VBD',
#  'beat/VB',
#  'released/VBN',
#  'concluded/VBD',
#  'inflated/VBN',
#  'teach/VBP',
#  'surfaced/VBN',
#  'suspects/VBZ',
#  'revising/VBG',
#  'booming/VBG',
#  'telegraph/VBP',
#  'concentrate/VB',
#  'mean/VBP',
#  'mean/VB',
#  'posted/VBN',
#  'posts/VBZ',
#  'use/VBP',
#  'stressing/VBG',
#  'rates/VBZ',
#  ...]

# %%
cfd1 = nltk.ConditionalFreqDist(wsj)

# %%
cfd1['yield'].keys()
# Out:
# dict_keys(['NN', 'VB'])

# %%
cfd1['cut'].keys()
# Out:
# dict_keys(['VBD', 'VB', 'VBN', 'NN'])

# %%
cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)

# %%
cfd2['NNP'].keys()
# Out:
# dict_keys(['Pierre', 'Vinken', 'Nov.', 'Mr.', 'Elsevier', 'N.V.', 'Dutch', 'Rudolph', 'Agnew', 'Consolidated', 'Gold', 'Fields', 'PLC', 'Kent', 'Lorillard', 'Inc.', 'Loews', 'Corp.', 'New', 'England', 'Journal', 'Medicine', 'James', 'A.', 'Talcott', 'Boston', 'Dana-Farber', 'Cancer', 'Institute', 'Dr.', 'National', 'Harvard', 'University', 'West', 'Groton', 'Mass.', 'Hollingsworth', 'Vose', 'Co.', 'U.S.', 'Brooke', 'T.', 'Mossman', 'Vermont', 'College', 'July', 'Environmental', 'Protection', 'Agency', 'Darrell', 'Phillips', 'IBC', 'Money', 'Fund', 'Report', 'Tuesday', 'August', 'Donoghue', 'Brenda', 'Malizia', 'Negus', 'Treasury', 'Monday', 'Dreyfus', 'World-Wide', 'Dollar', 'J.P.', 'Bolduc', 'W.R.', 'Grace', 'Terrence', 'D.', 'Daniels', 'Energy', 'Pacific', 'First', 'Financial', 'Royal', 'Trustco', 'Ltd.', 'Toronto', 'McDermott', 'International', 'Babcock', 'Wilcox', 'Bailey', 'Controls', 'Operations', 'Finmeccanica', 'S.p', 'Wickliffe', 'Ohio', 'Congress', 'House', 'Senate', 'Clark', 'J.', 'Vitulli', 'Mazda', 'Motor', 'Corp', 'Chrysler', 'Boca', 'Raton', 'Hot', 'Springs', 'Association', 'Manufacturers', 'Hoosier', 'Indianapolis', 'Rust', 'Belt', 'Du', 'Pont', 'Maytag', 'Trojan', 'Steel', 'Valley', 'Queen', 'Cheese', 'Factory', 'Mayor', 'William', 'H.', 'Hudnut', 'III', 'Symphony', 'Orchestra', 'Victor', 'Borge', 'Speedway', 'Fortune', 'Indiana', 'Roof', 'February', 'South', 'Korea', 'October', 'Wednesday', 'Trade', 'Industry', 'Ministry', 'January', 'Newsweek', 'Time', 'Washington', 'Post', 'Warner', 'Mortimer', 'B.', 'Zuckerman', 'News', 'World', 'Alan', 'Spoon', 'mid-October', 'Circulation', 'Credit', 'Plan', 'Publishers', 'Information', 'Bureau', 'Audit', 'Circulations', 'Electric', 'System', 'Public', 'Service', 'Hampshire', 'United', 'Illuminating', 'Northeast', 'Utilities', 'PS', 'Westborough', 'Haven', 'Conn.', 'Hartford', 'Conn', 'Manchester', 'N.H.', 'John', 'Rowe', 'Wilbur', 'Ross', 'Jr.', 'Rothschild', 'Federal', 'Regulatory', 'Commission', 'FERC', 'York', 'Stock', 'Exchange', 'Norman', 'Ricken', 'R', 'Us', 'Frederick', 'Deane', 'Signet', 'Banking', 'Daniel', 'M.', 'Rexinger', 'Circuit', 'City', 'Robert', 'R.', 'Glauber', 'Commonwealth', 'Edison', 'Illinois', 'Commerce', 'Judge', 'Richard', 'Curry', 'April', 'Feb.', 'Dec.', 'Byron', 'Rockford', 'Ill.', 'Supreme', 'Court', 'Appellate', 'Braidwood', 'LaSalle', 'I', 'Japan', 'Automobile', 'September', 'March', 'Texas', 'Chinchon', 'Seoul', 'Cray', 'Computer', 'Seymour', 'Research', 'Cray-3', 'May', 'Gregory', 'Barnum', 'Gary', 'P.', 'Smaby', 'Group', 'Minneapolis', 'SEC', 'Business', 'Hitachi', 'NEC', 'Fujitsu', 'Ltd', 'Nasdaq', 'Colorado', 'Colo.', 'Messrs.', 'Neil', 'Davenport', 'Joseph', 'Blanchard', 'Malcolm', 'Hammerton', 'Douglas', 'Wheeland', 'Stevens', 'Donald', 'Pardus', 'Arthur', 'Hatch', 'Eastern', 'Carney', 'Tassinari', 'Taiwan', 'Saudi', 'Arabia', 'China', 'Thailand', 'India', 'Brazil', 'Mexico', 'Representative', 'Carla', 'Hills', 'Mrs.', 'Taipei', 'Italy', 'Canada', 'Greece', 'Spain', 'Hoffman', 'Turkey', 'Malaysia', 'Argentina', 'Economy', 'Minister', 'Nestor', 'Rapanelli', 'Latin', 'American', 'Miguel', 'Alurralde', 'Assistant', 'Secretary', 'David', 'Mulford', 'Carlos', 'Carballo', 'President', 'Menem', 'The', 'Wall', 'Street', 'Apple', 'II', 'Commodore', 'Pet', 'Tandy', 'TRS-80', 'Stephen', 'Wozniak', 'Steven', 'Jobs', 'Homebrew', 'Club', 'Altair', 'Sol', 'IMSAI', 'Gates', 'Paul', 'Allen', 'IBM', 'F.', 'Shugart', 'Seagate', 'Technology', 'Dennis', 'Hayes', 'Dale', 'Heatherington', 'Atlanta', 'F.H.', 'Faulding', 'Moleculon', 'Kalipharma', 'Purepac', 'Australia', 'Bass', 'Strait', 'Whiting', 'Esso', 'Exxon', 'Broken', 'Hill', 'Pty.', 'Perch', 'Dolphin', 'Seahorse', 'Tarwhine', 'R.P.', 'Scherer', 'Southern', 'Optical', 'Thomas', 'Sloan', 'Shearson', 'Lehman', 'Hutton', 'White', 'Bush', 'Virgin', 'Timex', 'Generalized', 'Philippines', 'Magna', 'McAlpine', 'Frank', 'Stronach', 'Akerfeldt', 'Class', 'A', 'Parliament', 'Manfred', 'Gingl', 'Lord', 'Chilver ...

# %%
cfd2.keys()
# Out:
# dict_keys(['NNP', ',', 'CD', 'NNS', 'JJ', 'MD', 'VB', 'DT', 'NN', 'IN', '.', 'VBZ', 'VBG', 'CC', 'VBD', 'VBN', '-NONE-', 'RB', 'TO', 'PRP', 'RBR', 'WDT', 'VBP', 'RP', 'PRP$', 'JJS', 'POS', '``', 'EX', "''", 'WP', ':', 'JJR', 'WRB', '$', 'NNPS', 'WP$', '-LRB-', '-RRB-', 'PDT', 'RBS', 'FW', 'UH', 'SYM', 'LS', '#', 'VN', 'V', 'N'])

# %% [markdown]
# ### Unsimplified Tags

# %%
def findtags(tag_prefix, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text if tag.startswith(tag_prefix))
    return dict((tag, cfd[tag].keys()[:5]) for tag in cfd.conditions())

# %%
tagdict = findtags('NN', nltk.corpus.brown.tagged_words(categories='news'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-a3ebd0a34749> in <module>()
# ----> 1 tagdict = findtags('NN', nltk.corpus.brown.tagged_words(categories='news'))
#
# <ipython-input-49-b4f3262edfa7> in findtags(tag_prefix, tagged_text)
#       1 def findtags(tag_prefix, tagged_text):
#       2     cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text if tag.startswith(tag_prefix))
# ----> 3     return dict((tag, cfd[tag].keys()[:5]) for tag in cfd.conditions())
#
# <ipython-input-49-b4f3262edfa7> in <genexpr>(.0)
#       1 def findtags(tag_prefix, tagged_text):
#       2     cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text if tag.startswith(tag_prefix))
# ----> 3     return dict((tag, cfd[tag].keys()[:5]) for tag in cfd.conditions())
#
# TypeError: 'dict_keys' object is not subscriptable
